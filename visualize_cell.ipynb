# %%
import matplotlib.pyplot as plt
import numpy as np
from place_cells import PlaceCells
from hd_cells import HDCells

# %matplotlib inline

# %%
hd_cells = HDCells()

for i in range(10+1):
    angle = 0.1 * i * 2.0 * np.pi - np.pi    
    h = hd_cells.get_activation(angle)
    plt.plot(h)

# %%
place_cells = PlaceCells()

for i in range(10+1):
    x = 0.1 * i * 9.0 - 4.5
    pos = (x,x)
    c = place_cells.get_activation(pos)
    plt.plot(c)
